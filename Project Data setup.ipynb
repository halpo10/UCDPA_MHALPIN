# %%
import pandas as pd
import numpy as np
covid_data= pd.read_csv('current covid.csv',index_col = 0)
covid_data
# Out:
#          state  positive  probableCases    negative  pending  \
# date
# 20210307    AK     56886            NaN         NaN      NaN
# 20210307    AL    499819       107742.0   1931711.0      NaN
# 20210307    AR    324818        69092.0   2480716.0      NaN
# 20210307    AS         0            NaN      2140.0      NaN
# 20210307    AZ    826454        56519.0   3073010.0      NaN
# 20210307    CA   3501394            NaN         NaN      NaN
# 20210307    CO    436602        24786.0   2199458.0      NaN
# 20210307    CT    285330        19621.0         NaN      NaN
# 20210307    DC     41419            NaN         NaN      NaN
# 20210307    DE     88354         4733.0    545070.0      NaN
# 20210307    FL   1909209       360372.0   9339038.0   8544.0
# 20210307    GA   1023487       195151.0         NaN      NaN
# 20210307    GU      7749          209.0    112887.0      NaN
# 20210307    HI     28699          808.0         NaN      NaN
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\mhalpin\\UCD Programme\\API\\UCDPA_MHALPIN'

# %%
covid_data.head()
# Out:
#          state  positive  probableCases   negative  pending  \
# date
# 20210307    AK     56886            NaN        NaN      NaN
# 20210307    AL    499819       107742.0  1931711.0      NaN
# 20210307    AR    324818        69092.0  2480716.0      NaN
# 20210307    AS         0            NaN     2140.0      NaN
# 20210307    AZ    826454        56519.0  3073010.0      NaN
#
#          totalTestResultsSource  totalTestResults  hospitalizedCurrently  \
# date
# 20210307        totalTestsViral           1731628                   33.0
# 20210307  totalTestsPeopleViral           2323788                  494.0
# 20210307        totalTestsViral           2736442                  335.0
# 20210307        totalTestsViral              2140                    NaN
# 20210307        totalTestsViral           7908105                  963.0
#
#           hospitalizedCumulative  inIcuCurrently  ...  dataQualityGrade  \
# date                                              ...
# ...

# %%
covid_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56 entries, 20210307 to 20210307
# Data columns (total 55 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   state                        56 non-null     object
#  1   positive                     56 non-null     int64
#  2   probableCases                36 non-null     float64
#  3   negative                     35 non-null     float64
#  4   pending                      5 non-null      float64
#  5   totalTestResultsSource       56 non-null     object
#  6   totalTestResults             56 non-null     int64
#  7   hospitalizedCurrently        53 non-null     float64
#  8   hospitalizedCumulative       36 non-null     float64
#  9   inIcuCurrently               42 non-null     float64
#  10  inIcuCumulative              12 non-null     float64
#  11  onVentilatorCurrently        32 non-null     float64
# ...

# %%
covid_data.shape
# Out:
# (56, 55)

# %%
covid_data.describe
# Out:
# <bound method NDFrame.describe of          state  positive  probableCases    negative  pending  \
# date
# 20210307    AK     56886            NaN         NaN      NaN
# 20210307    AL    499819       107742.0   1931711.0      NaN
# 20210307    AR    324818        69092.0   2480716.0      NaN
# 20210307    AS         0            NaN      2140.0      NaN
# 20210307    AZ    826454        56519.0   3073010.0      NaN
# 20210307    CA   3501394            NaN         NaN      NaN
# 20210307    CO    436602        24786.0   2199458.0      NaN
# 20210307    CT    285330        19621.0         NaN      NaN
# 20210307    DC     41419            NaN         NaN      NaN
# 20210307    DE     88354         4733.0    545070.0      NaN
# 20210307    FL   1909209       360372.0   9339038.0   8544.0
# 20210307    GA   1023487       195151.0         NaN      NaN
# 20210307    GU      7749          209.0    112887.0      NaN
# 20210307    HI     28699          808.0         NaN      NaN
# ...

# %%
#what states had the most positive cases up to Mar 2021!
covid_data.sort_values("positive", ascending = False)
# Out:
#          state  positive  probableCases    negative  pending  \
# date
# 20210307    CA   3501394            NaN         NaN      NaN
# 20210307    TX   2686818       365961.0         NaN      NaN
# 20210307    FL   1909209       360372.0   9339038.0   8544.0
# 20210307    NY   1681169            NaN         NaN      NaN
# 20210307    IL   1198335            NaN         NaN      NaN
# 20210307    GA   1023487       195151.0         NaN      NaN
# 20210307    OH    978471       142113.0         NaN      NaN
# 20210307    PA    948643       134103.0   3942124.0      NaN
# 20210307    NC    872176       112559.0         NaN      NaN
# 20210307    AZ    826454        56519.0   3073010.0      NaN
# 20210307    NJ    812609        91670.0  10186941.0      NaN
# 20210307    TN    782206       128301.0         NaN      NaN
# 20210307    IN    667262            NaN   2483156.0      NaN
# 20210307    MI    656072        60018.0         NaN      NaN
# ...

# %%
dropcolumns =covid_data.dropna(axis=1)
print(covid_data.shape, dropcolumns.shape)
# Out:
# (56, 55) (56, 19)

# %%
covid_data.shape
# Out:
# (56, 55)

# %%
covid_data.isna().any()
# Out:
# state                          False
# positive                       False
# probableCases                   True
# negative                        True
# pending                         True
# totalTestResultsSource         False
# totalTestResults               False
# hospitalizedCurrently           True
# hospitalizedCumulative          True
# inIcuCurrently                  True
# inIcuCumulative                 True
# onVentilatorCurrently           True
# onVentilatorCumulative          True
# recovered                       True
# lastUpdateEt                    True
# dateModified                    True
# checkTimeEt                     True
# death                          False
# hospitalized                    True
# hospitalizedDischarged          True
# dateChecked                     True
# totalTestsViral                 True
# positiveTestsViral              True
# negativeTestsViral              True
# positiveCasesViral              True
# ...

# %%
#Drop duplicates in state field
drop_duplicates=(covid_data.drop_duplicates(subset=["state"]))
print(covid_data.shape, drop_duplicates.shape)
# Out:
# (56, 55) (56, 55)

# %%
#what states had the lease positive cases up to Mar 2021!
covid_data.sort_values("positive")
# Out:
#          state  positive  probableCases    negative  pending  \
# date
# 20210307    AS         0            NaN      2140.0      NaN
# 20210307    MP       145            NaN     17429.0      NaN
# 20210307    VI      2714            NaN     46167.0     80.0
# 20210307    GU      7749          209.0    112887.0      NaN
# 20210307    VT     16083          448.0    320060.0      NaN
# 20210307    HI     28699          808.0         NaN      NaN
# 20210307    DC     41419            NaN         NaN      NaN
# 20210307    ME     45794         9948.0         NaN      NaN
# 20210307    WY     54764         8367.0    182264.0      NaN
# 20210307    AK     56886            NaN         NaN      NaN
# 20210307    NH     76861        22797.0    579582.0      NaN
# 20210307    DE     88354         4733.0    545070.0      NaN
# 20210307    ND    100391         5463.0    305912.0      NaN
# 20210307    MT    100914         5524.0         NaN      NaN
# ...

# %%
Metrics =covid_data.loc[:, ["state","death","recovered","positive","totalTestResults"]]
Metrics
# Out:
#          state  death  recovered  positive  totalTestResults
# date
# 20210307    AK    305        NaN     56886           1731628
# 20210307    AL  10148   295690.0    499819           2323788
# 20210307    AR   5319   315517.0    324818           2736442
# 20210307    AS      0        NaN         0              2140
# 20210307    AZ  16328        NaN    826454           7908105
# 20210307    CA  54124        NaN   3501394          49646014
# 20210307    CO   5989        NaN    436602           6415123
# 20210307    CT   7704        NaN    285330           6520366
# 20210307    DC   1030    29570.0     41419           1261363
# 20210307    DE   1473        NaN     88354           1431942
# 20210307    FL  32266        NaN   1909209          22339182
# 20210307    GA  17906        NaN   1023487           7359069
# 20210307    GU    133     7590.0      7749            120636
# 20210307    HI    445        NaN     28699           1146796
# ...

# %%
#positive ratio from total test results(PR)
Metrics["positive rate"]=Metrics['positive']/Metrics['totalTestResults']

# %%
#what states had the highest posiive rate up to Mar 2021!
positive_rate=Metrics.sort_values("positive rate", ascending = False)
positive_rate
# Out:
#          state  death  recovered  positive  totalTestResults  positive rate
# date
# 20210307    ID   1879    96017.0    172931            645838       0.267762
# 20210307    PR   2062    91987.0    101632            407604       0.249340
# 20210307    KS   4812        NaN    295861           1270547       0.232861
# 20210307    AL  10148   295690.0    499819           2323788       0.215088
# 20210307    IA   5558   320054.0    282384           1326802       0.212831
# 20210307    MS   6808   278162.0    297581           1756955       0.169373
# 20210307    SD   1900   109531.0    113589            701924       0.161825
# 20210307    GA  17906        NaN   1023487           7359069       0.139078
# 20210307    TX  44451  2502609.0   2686818          19907384       0.134966
# 20210307    UT   1976   358958.0    374850           2910121       0.128809
# 20210307    OK   4534   412177.0    428997           3575297       0.119989
# ...

# %%
#death ratio from positive results
Metrics["death rate"]=Metrics['death']/Metrics['positive']

# %%
#what states had the highest deaths up to Mar 2021!
Metrics.sort_values("death", ascending = False)
# Out:
#          state  death  recovered  positive  totalTestResults  positive rate  \
# date
# 20210307    CA  54124        NaN   3501394          49646014       0.070527
# 20210307    TX  44451  2502609.0   2686818          19907384       0.134966
# 20210307    NY  39029        NaN   1681169          39695100       0.042352
# 20210307    FL  32266        NaN   1909209          22339182       0.085465
# 20210307    PA  24349   861756.0    948643          10681716       0.088810
# 20210307    NJ  23574        NaN    812609          10999550       0.073877
# 20210307    IL  23014        NaN   1198335          18640190       0.064288
# 20210307    GA  17906        NaN   1023487           7359069       0.139078
# 20210307    OH  17656   925655.0    978471          10257157       0.095394
# 20210307    MI  16658   549881.0    656072          10621967       0.061766
# 20210307    MA  16417   508745.0    591356          16825551       0.035146
# ...

# %%
#what states had the highest death rate up to Mar 2021!
Metrics.sort_values("death rate", ascending = False)
# Out:
#          state  death  recovered  positive  totalTestResults  positive rate  \
# date
# 20210307    NJ  23574        NaN    812609          10999550       0.073877
# 20210307    MA  16417   508745.0    591356          16825551       0.035146
# 20210307    CT   7704        NaN    285330           6520366       0.043760
# 20210307    PA  24349   861756.0    948643          10681716       0.088810
# 20210307    MI  16658   549881.0    656072          10621967       0.061766
# 20210307    DC   1030    29570.0     41419           1261363       0.032837
# 20210307    NY  39029        NaN   1681169          39695100       0.042352
# 20210307    MS   6808   278162.0    297581           1756955       0.169373
# 20210307    LA   9748   415954.0    433785           5695464       0.076163
# 20210307    MD   7955     9703.0    387319           8097590       0.047831
# 20210307    NM   3808   156554.0    186922           2783542       0.067153
# ...

# %%
positive_rate[positive_rate['positive rate']>0.12]
# Out:
#          state  death  recovered  positive  totalTestResults  positive rate
# date
# 20210307    ID   1879    96017.0    172931            645838       0.267762
# 20210307    PR   2062    91987.0    101632            407604       0.249340
# 20210307    KS   4812        NaN    295861           1270547       0.232861
# 20210307    AL  10148   295690.0    499819           2323788       0.215088
# 20210307    IA   5558   320054.0    282384           1326802       0.212831
# 20210307    MS   6808   278162.0    297581           1756955       0.169373
# 20210307    SD   1900   109531.0    113589            701924       0.161825
# 20210307    GA  17906        NaN   1023487           7359069       0.139078
# 20210307    TX  44451  2502609.0   2686818          19907384       0.134966
# 20210307    UT   1976   358958.0    374850           2910121       0.128809

# %%
# comparing states with high death rates and positive rates from above table shows little correlation between states!
Metrics[Metrics['death rate']>0.02]
# Out:
#          state  death  recovered  positive  totalTestResults  positive rate  \
# date
# 20210307    AL  10148   295690.0    499819           2323788       0.215088
# 20210307    CT   7704        NaN    285330           6520366       0.043760
# 20210307    DC   1030    29570.0     41419           1261363       0.032837
# 20210307    LA   9748   415954.0    433785           5695464       0.076163
# 20210307    MA  16417   508745.0    591356          16825551       0.035146
# 20210307    MD   7955     9703.0    387319           8097590       0.047831
# 20210307    MI  16658   549881.0    656072          10621967       0.061766
# 20210307    MS   6808   278162.0    297581           1756955       0.169373
# 20210307    NJ  23574        NaN    812609          10999550       0.073877
# 20210307    NM   3808   156554.0    186922           2783542       0.067153
# 20210307    NY  39029        NaN   1681169          39695100       0.042352
# ...

# %%
import pandas as pd
import numpy as np
ethnic_data= pd.read_csv("racial-ethnic data.csv")
ethnic_data
# Out:
#           Date State  Cases_Total  Cases_White  Cases_Black  Cases_Latinx  \
# 0     20210307    AK      59332.0      18300.0       1499.0           NaN
# 1     20210307    AL     499819.0     160347.0      82790.0           NaN
# 2     20210307    AR     324818.0     207596.0      50842.0           NaN
# 3     20210307    AS          NaN          NaN          NaN           NaN
# 4     20210307    AZ     826454.0     308453.0      25775.0      244539.0
# ...        ...   ...          ...          ...          ...           ...
# 5315  20200412    VT          NaN          NaN          NaN           NaN
# 5316  20200412    WA      10411.0       2903.0        289.0        1180.0
# 5317  20200412    WI       3341.0       1680.0        857.0           NaN
# 5318  20200412    WV          NaN          NaN          NaN           NaN
# 5319  20200412    WY          NaN          NaN          NaN           NaN
#
#       Cases_Asian  Cases_AIAN  Cases_NHPI  Cases_Multiracial  ...  \
# ...

# %%
ethnic_data.head()
# Out:
#        Date State  Cases_Total  Cases_White  Cases_Black  Cases_Latinx  \
# 0  20210307    AK      59332.0      18300.0       1499.0           NaN
# 1  20210307    AL     499819.0     160347.0      82790.0           NaN
# 2  20210307    AR     324818.0     207596.0      50842.0           NaN
# 3  20210307    AS          NaN          NaN          NaN           NaN
# 4  20210307    AZ     826454.0     308453.0      25775.0      244539.0
#
#    Cases_Asian  Cases_AIAN  Cases_NHPI  Cases_Multiracial  ...  Tests_Latinx  \
# 0       2447.0     12238.0      1508.0             4453.0  ...           NaN
# 1       2273.0         NaN         NaN                NaN  ...           NaN
# 2       2913.0      1070.0      3358.0             1804.0  ...           NaN
# 3          NaN         NaN         NaN                NaN  ...           NaN
# 4      11921.0     40707.0         NaN                NaN  ...           NaN
#
#    Tests_Asian  Tests_AIAN  Tests_NHPI  Tests_Multiracial  Tests_Other  \
# ...

# %%
ethnic_data.shape
# Out:
# (5320, 54)

# %%
dropcolumns =ethnic_data.dropna(axis=1)
print(ethnic_data.shape, dropcolumns.shape)
# Out:
# (5320, 54) (5320, 2)

# %%
ethnic_date= ethnic_data[ethnic_data['Date']==20210307]
ethnic_date
# Out:
#         Date State  Cases_Total  Cases_White  Cases_Black  Cases_Latinx  \
# 0   20210307    AK      59332.0      18300.0       1499.0           NaN
# 1   20210307    AL     499819.0     160347.0      82790.0           NaN
# 2   20210307    AR     324818.0     207596.0      50842.0           NaN
# 3   20210307    AS          NaN          NaN          NaN           NaN
# 4   20210307    AZ     826454.0     308453.0      25775.0      244539.0
# 5   20210307    CA    3501394.0     546630.0     111279.0     1509103.0
# 6   20210307    CO     435762.0     181669.0      12637.0      119224.0
# 7   20210307    CT     285330.0      85469.0      19651.0       41523.0
# 8   20210307    DC      41419.0      10708.0      20164.0           NaN
# 9   20210307    DE      88354.0      42730.0      19768.0       14532.0
# 10  20210307    FL    1944995.0     664121.0     237772.0      608165.0
# 11  20210307    GA    1023487.0     319208.0     216068.0       85460.0
# ...

# %%
ethnic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5320 entries, 0 to 5319
# Data columns (total 54 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Date                          5320 non-null   int64
#  1   State                         5320 non-null   object
#  2   Cases_Total                   5088 non-null   float64
#  3   Cases_White                   4668 non-null   float64
#  4   Cases_Black                   4587 non-null   float64
#  5   Cases_Latinx                  2072 non-null   float64
#  6   Cases_Asian                   4370 non-null   float64
#  7   Cases_AIAN                    3263 non-null   float64
#  8   Cases_NHPI                    2181 non-null   float64
#  9   Cases_Multiracial             1525 non-null   float64
#  10  Cases_Other                   4472 non-null   float64
#  11  Cases_Unknown                 5059 non-null   float64
# ...

# %%
ethnic_date=ethnic_data[0:56]
ethnic_date
# Out:
#         Date State  Cases_Total  Cases_White  Cases_Black  Cases_Latinx  \
# 0   20210307    AK      59332.0      18300.0       1499.0           NaN
# 1   20210307    AL     499819.0     160347.0      82790.0           NaN
# 2   20210307    AR     324818.0     207596.0      50842.0           NaN
# 3   20210307    AS          NaN          NaN          NaN           NaN
# 4   20210307    AZ     826454.0     308453.0      25775.0      244539.0
# 5   20210307    CA    3501394.0     546630.0     111279.0     1509103.0
# 6   20210307    CO     435762.0     181669.0      12637.0      119224.0
# 7   20210307    CT     285330.0      85469.0      19651.0       41523.0
# 8   20210307    DC      41419.0      10708.0      20164.0           NaN
# 9   20210307    DE      88354.0      42730.0      19768.0       14532.0
# 10  20210307    FL    1944995.0     664121.0     237772.0      608165.0
# 11  20210307    GA    1023487.0     319208.0     216068.0       85460.0
# ...

# %%
metrics_ethnic_data=Metrics.merge(ethnic_date, left_on=['state'], right_on=['State'])
metrics_ethnic_data
# Out:
#    state  death  recovered  positive  totalTestResults  positive rate  \
# 0     AK    305        NaN     56886           1731628       0.032851
# 1     AL  10148   295690.0    499819           2323788       0.215088
# 2     AR   5319   315517.0    324818           2736442       0.118701
# 3     AS      0        NaN         0              2140       0.000000
# 4     AZ  16328        NaN    826454           7908105       0.104507
# 5     CA  54124        NaN   3501394          49646014       0.070527
# 6     CO   5989        NaN    436602           6415123       0.068058
# 7     CT   7704        NaN    285330           6520366       0.043760
# 8     DC   1030    29570.0     41419           1261363       0.032837
# 9     DE   1473        NaN     88354           1431942       0.061702
# 10    FL  32266        NaN   1909209          22339182       0.085465
# 11    GA  17906        NaN   1023487           7359069       0.139078
# ...

# %%
#duplicate check
metrics_ethnic_data.shape
# Out:
# (56, 61)

# %%
import pandas as pd
import numpy as np
region_data= pd.read_csv("regions.csv")
region_data
# Out:
#    State     Region
# 0     AK       west
# 1     AL      south
# 2     AR      south
# 3     AS     Other
# 4     AZ       west
# 5     CA       west
# 6     CO       west
# 7     CT  northeast
# 8     DC      south
# 9     DE      south
# 10    FL      south
# 11    GA      south
# 12    GU     Other
# 13    HI       west
# 14    IA    midwest
# 15    ID       west
# 16    IL    midwest
# 17    IN    midwest
# 18    KS    midwest
# 19    KY      south
# 20    LA      south
# 21    MA  northeast
# 22    MD  northeast
# 23    ME  northeast
# 24    MI    midwest
# 25    MN    midwest
# 26    MO    midwest
# 27    MP     Other
# 28    MS      south
# 29    MT       west
# 30    NC      south
# 31    ND    midwest
# 32    NE    midwest
# 33    NH  northeast
# 34    NJ  northeast
# 35    NM       west
# 36    NV       west
# 37    NY  northeast
# 38    OH    midwest
# 39    OK      south
# 40    OR       west
# 41    PA  northeast
# 42    PR     Other
# 43    RI  northeast
# ...

# %%
joined_data=metrics_ethnic_data.merge(region_data)
joined_data
# Out:
#    state  death  recovered  positive  totalTestResults  positive rate  \
# 0     AK    305        NaN     56886           1731628       0.032851
# 1     AL  10148   295690.0    499819           2323788       0.215088
# 2     AR   5319   315517.0    324818           2736442       0.118701
# 3     AS      0        NaN         0              2140       0.000000
# 4     AZ  16328        NaN    826454           7908105       0.104507
# 5     CA  54124        NaN   3501394          49646014       0.070527
# 6     CO   5989        NaN    436602           6415123       0.068058
# 7     CT   7704        NaN    285330           6520366       0.043760
# 8     DC   1030    29570.0     41419           1261363       0.032837
# 9     DE   1473        NaN     88354           1431942       0.061702
# 10    FL  32266        NaN   1909209          22339182       0.085465
# 11    GA  17906        NaN   1023487           7359069       0.139078
# ...

# %%
#duplicate check
joined_data.shape
# Out:
# (56, 62)

# %%
regionsgrouped=joined_data.groupby(['Region']).mean()
regionsgrouped
# Out:
#                   death      recovered       positive  totalTestResults  \
# Region
# Other        444.400000   25541.250000   22448.000000      1.193670e+05
# midwest     8978.583333  398731.125000  507308.250000      6.138806e+06
# northeast  12367.300000  246673.833333  497394.500000      1.002248e+07
# south      11388.875000  490805.727273  690274.250000      6.398872e+06
# west        7637.769231  152604.400000  502939.769231      6.688913e+06
#
#            positive rate  death rate        Date  Cases_Total    Cases_White  \
# Region
# Other           0.075470    0.015114  20210307.0     27983.75     418.000000
# midwest         0.110514    0.016776  20210307.0    511964.00  299704.333333
# northeast       0.046623    0.021673  20210307.0    497328.50  149239.222222
# south           0.107414    0.017200  20210307.0    692590.75  239835.062500
# west            0.088615    0.013746  20210307.0    503017.00  138632.000000
#
# ...

# %%
#In what region is the death rate highest?
regionsgrouped.sort_values("death rate", ascending = False)
# Out:
#                   death      recovered       positive  totalTestResults  \
# Region
# northeast  12367.300000  246673.833333  497394.500000      1.002248e+07
# south      11388.875000  490805.727273  690274.250000      6.398872e+06
# midwest     8978.583333  398731.125000  507308.250000      6.138806e+06
# Other        444.400000   25541.250000   22448.000000      1.193670e+05
# west        7637.769231  152604.400000  502939.769231      6.688913e+06
#
#            positive rate  death rate        Date  Cases_Total    Cases_White  \
# Region
# northeast       0.046623    0.021673  20210307.0    497328.50  149239.222222
# south           0.107414    0.017200  20210307.0    692590.75  239835.062500
# midwest         0.110514    0.016776  20210307.0    511964.00  299704.333333
# Other           0.075470    0.015114  20210307.0     27983.75     418.000000
# west            0.088615    0.013746  20210307.0    503017.00  138632.000000
#
# ...

# %%
#In what region is the positive rate highest?
regionsgrouped.sort_values("positive rate", ascending = False)
# Out:
#                   death      recovered       positive  totalTestResults  \
# Region
# midwest     8978.583333  398731.125000  507308.250000      6.138806e+06
# south      11388.875000  490805.727273  690274.250000      6.398872e+06
# west        7637.769231  152604.400000  502939.769231      6.688913e+06
# Other        444.400000   25541.250000   22448.000000      1.193670e+05
# northeast  12367.300000  246673.833333  497394.500000      1.002248e+07
#
#            positive rate  death rate        Date  Cases_Total    Cases_White  \
# Region
# midwest         0.110514    0.016776  20210307.0    511964.00  299704.333333
# south           0.107414    0.017200  20210307.0    692590.75  239835.062500
# west            0.088615    0.013746  20210307.0    503017.00  138632.000000
# Other           0.075470    0.015114  20210307.0     27983.75     418.000000
# northeast       0.046623    0.021673  20210307.0    497328.50  149239.222222
#
# ...

# %%
regions_stategrouped=joined_data.groupby(['Region','state']).mean()
regions_stategrouped
# Out:
#                    death  recovered   positive  totalTestResults  \
# Region    state
# Other     AS         0.0        NaN        0.0            2140.0
#           GU       133.0     7590.0     7749.0          120636.0
#           MP         2.0       29.0      145.0           17574.0
#           PR      2062.0    91987.0   101632.0          407604.0
#           VI        25.0     2559.0     2714.0           48881.0
# midwest   IA      5558.0   320054.0   282384.0         1326802.0
#           IL     23014.0        NaN  1198335.0        18640190.0
#           IN     12737.0        NaN   667262.0         8242367.0
#           KS      4812.0        NaN   295861.0         1270547.0
#           MI     16658.0   549881.0   656072.0        10621967.0
#           MN      6550.0   476055.0   490011.0         7111428.0
#           MO      8161.0        NaN   480643.0         4565866.0
#           ND      1478.0    98326.0   100391.0         1425146.0
# ...

# %%
#Conditional formatting

regions_stategrouped['death detail']=regions_stategrouped.apply(lambda x: 'high' if x['death rate'] > 0.02 
  else 'lower', axis =1)
regions_stategrouped
# Out:
#                    death  recovered   positive  totalTestResults  \
# Region    state
# Other     AS         0.0        NaN        0.0            2140.0
#           GU       133.0     7590.0     7749.0          120636.0
#           MP         2.0       29.0      145.0           17574.0
#           PR      2062.0    91987.0   101632.0          407604.0
#           VI        25.0     2559.0     2714.0           48881.0
# midwest   IA      5558.0   320054.0   282384.0         1326802.0
#           IL     23014.0        NaN  1198335.0        18640190.0
#           IN     12737.0        NaN   667262.0         8242367.0
#           KS      4812.0        NaN   295861.0         1270547.0
#           MI     16658.0   549881.0   656072.0        10621967.0
#           MN      6550.0   476055.0   490011.0         7111428.0
#           MO      8161.0        NaN   480643.0         4565866.0
#           ND      1478.0    98326.0   100391.0         1425146.0
# ...

# %%
regions_stategrouped[regions_stategrouped['death detail']=='high']
# Out:
#                    death  recovered   positive  totalTestResults  \
# Region    state
# Other     PR      2062.0    91987.0   101632.0          407604.0
# midwest   MI     16658.0   549881.0   656072.0        10621967.0
# northeast CT      7704.0        NaN   285330.0         6520366.0
#           MA     16417.0   508745.0   591356.0        16825551.0
#           MD      7955.0     9703.0   387319.0         8097590.0
#           NJ     23574.0        NaN   812609.0        10999550.0
#           NY     39029.0        NaN  1681169.0        39695100.0
#           PA     24349.0   861756.0   948643.0        10681716.0
# south     AL     10148.0   295690.0   499819.0         2323788.0
#           DC      1030.0    29570.0    41419.0         1261363.0
#           LA      9748.0   415954.0   433785.0         5695464.0
#           MS      6808.0   278162.0   297581.0         1756955.0
# west      NM      3808.0   156554.0   186922.0         2783542.0
#
# ...
