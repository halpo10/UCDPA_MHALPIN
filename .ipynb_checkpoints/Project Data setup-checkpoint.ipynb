# %%
import pandas as pd
import numpy as np
covid_data= pd.read_csv('current covid.csv',index_col = 0)
covid_data
# Out:
#          state  positive  probableCases    negative  pending  \
# date
# 20210307    AK     56886            NaN         NaN      NaN
# 20210307    AL    499819       107742.0   1931711.0      NaN
# 20210307    AR    324818        69092.0   2480716.0      NaN
# 20210307    AS         0            NaN      2140.0      NaN
# 20210307    AZ    826454        56519.0   3073010.0      NaN
# 20210307    CA   3501394            NaN         NaN      NaN
# 20210307    CO    436602        24786.0   2199458.0      NaN
# 20210307    CT    285330        19621.0         NaN      NaN
# 20210307    DC     41419            NaN         NaN      NaN
# 20210307    DE     88354         4733.0    545070.0      NaN
# 20210307    FL   1909209       360372.0   9339038.0   8544.0
# 20210307    GA   1023487       195151.0         NaN      NaN
# 20210307    GU      7749          209.0    112887.0      NaN
# 20210307    HI     28699          808.0         NaN      NaN
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\mhalpin\\UCD Programme\\API\\UCDPA_MHALPIN'

# %%
covid_data.head()
# Out:
#          state  positive  probableCases   negative  pending  \
# date
# 20210307    AK     56886            NaN        NaN      NaN
# 20210307    AL    499819       107742.0  1931711.0      NaN
# 20210307    AR    324818        69092.0  2480716.0      NaN
# 20210307    AS         0            NaN     2140.0      NaN
# 20210307    AZ    826454        56519.0  3073010.0      NaN
#
#          totalTestResultsSource  totalTestResults  hospitalizedCurrently  \
# date
# 20210307        totalTestsViral           1731628                   33.0
# 20210307  totalTestsPeopleViral           2323788                  494.0
# 20210307        totalTestsViral           2736442                  335.0
# 20210307        totalTestsViral              2140                    NaN
# 20210307        totalTestsViral           7908105                  963.0
#
#           hospitalizedCumulative  inIcuCurrently  ...  dataQualityGrade  \
# date                                              ...
# ...

# %%
covid_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56 entries, 20210307 to 20210307
# Data columns (total 55 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   state                        56 non-null     object
#  1   positive                     56 non-null     int64
#  2   probableCases                36 non-null     float64
#  3   negative                     35 non-null     float64
#  4   pending                      5 non-null      float64
#  5   totalTestResultsSource       56 non-null     object
#  6   totalTestResults             56 non-null     int64
#  7   hospitalizedCurrently        53 non-null     float64
#  8   hospitalizedCumulative       36 non-null     float64
#  9   inIcuCurrently               42 non-null     float64
#  10  inIcuCumulative              12 non-null     float64
#  11  onVentilatorCurrently        32 non-null     float64
# ...

# %%
covid_data.shape
# Out:
# (56, 55)

# %%
covid_data.describe
# Out:
# <bound method NDFrame.describe of          state  positive  probableCases    negative  pending  \
# date
# 20210307    AK     56886            NaN         NaN      NaN
# 20210307    AL    499819       107742.0   1931711.0      NaN
# 20210307    AR    324818        69092.0   2480716.0      NaN
# 20210307    AS         0            NaN      2140.0      NaN
# 20210307    AZ    826454        56519.0   3073010.0      NaN
# 20210307    CA   3501394            NaN         NaN      NaN
# 20210307    CO    436602        24786.0   2199458.0      NaN
# 20210307    CT    285330        19621.0         NaN      NaN
# 20210307    DC     41419            NaN         NaN      NaN
# 20210307    DE     88354         4733.0    545070.0      NaN
# 20210307    FL   1909209       360372.0   9339038.0   8544.0
# 20210307    GA   1023487       195151.0         NaN      NaN
# 20210307    GU      7749          209.0    112887.0      NaN
# 20210307    HI     28699          808.0         NaN      NaN
# ...
